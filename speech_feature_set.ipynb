# %%
import opensmile

# %%
smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.ComParE_2016,
    feature_level=opensmile.FeatureLevel.LowLevelDescriptors,
)
ComParE_2016_LLD = smile.process_file(r'D:\Projects\Speech_Depression\data\train\audio_train\13193950052_2020_10_08_vad.wav')

# %%
ComParE_2016_LLD
# Out:
#                                                                                                   F0final_sma  \
# file                                               start                  end
# D:\Projects\Speech_Depression\data\train\audio_... 0 days 00:00:00        0 days 00:00:00.060000          0.0
#                                                    0 days 00:00:00.010000 0 days 00:00:00.070000          0.0
#                                                    0 days 00:00:00.020000 0 days 00:00:00.080000          0.0
#                                                    0 days 00:00:00.030000 0 days 00:00:00.090000          0.0
#                                                    0 days 00:00:00.040000 0 days 00:00:00.100000          0.0
# ...                                                                                                       ...
#                                                    0 days 00:00:52.410000 0 days 00:00:52.470000          0.0
# ...

# %%
smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.ComParE_2016,
    feature_level=opensmile.FeatureLevel.LowLevelDescriptors_Deltas,
)
ComParE_2016_LLDD = smile.process_file(r'D:\Projects\Speech_Depression\data\train\audio_train\13193950052_2020_10_08_vad.wav')

# %%
ComParE_2016_LLDD
# Out:
#                                                                                                   F0final_sma_de  \
# file                                               start                  end
# D:\Projects\Speech_Depression\data\train\audio_... 0 days 00:00:00        0 days 00:00:00.060000             0.0
#                                                    0 days 00:00:00.010000 0 days 00:00:00.070000             0.0
#                                                    0 days 00:00:00.020000 0 days 00:00:00.080000             0.0
#                                                    0 days 00:00:00.030000 0 days 00:00:00.090000             0.0
#                                                    0 days 00:00:00.040000 0 days 00:00:00.100000             0.0
# ...                                                                                                          ...
# ...

# %%
smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.eGeMAPSv02,
    feature_level=opensmile.FeatureLevel.LowLevelDescriptors,
)
eGeMAPSv02_LLD = smile.process_file(r'D:\Projects\Speech_Depression\data\train\audio_train\13193950052_2020_10_08_vad.wav')

# %%
eGeMAPSv02_LLD
# Out:
#                                                                                                   Loudness_sma3  \
# file                                               start                  end
# D:\Projects\Speech_Depression\data\train\audio_... 0 days 00:00:00        0 days 00:00:00.020000       0.226804
#                                                    0 days 00:00:00.010000 0 days 00:00:00.030000       0.284462
#                                                    0 days 00:00:00.020000 0 days 00:00:00.040000       0.394319
#                                                    0 days 00:00:00.030000 0 days 00:00:00.050000       0.491490
#                                                    0 days 00:00:00.040000 0 days 00:00:00.060000       0.597851
# ...                                                                                                         ...
#                                                    0 days 00:00:52.410000 0 days 00:00:52.430000       1.337053
# ...

# %%
smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.emobase,
    feature_level=opensmile.FeatureLevel.LowLevelDescriptors,
)
emobase_LLD = smile.process_file(r'D:\Projects\Speech_Depression\data\train\audio_train\13193950052_2020_10_08_vad.wav')

# %%
emobase_LLD
# Out:
#                                                                                                   pcm_intensity_sma  \
# file                                               start                  end
# D:\Projects\Speech_Depression\data\train\audio_... 0 days 00:00:00        0 days 00:00:00.025000       1.485159e-09
#                                                    0 days 00:00:00.010000 0 days 00:00:00.035000       4.384611e-08
#                                                    0 days 00:00:00.020000 0 days 00:00:00.045000       7.942526e-08
#                                                    0 days 00:00:00.030000 0 days 00:00:00.055000       1.396199e-07
#                                                    0 days 00:00:00.040000 0 days 00:00:00.065000       1.328228e-07
# ...                                                                                                             ...
# ...

# %%
smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.emobase,
    feature_level=opensmile.FeatureLevel.Functionals,
)
emobase_Fun = smile.process_file(r'D:\Projects\Speech_Depression\data\train\audio_train\13193950052_2020_10_08_vad.wav')

# %%
emobase_Fun
# Out:
#                                                                                   pcm_intensity_sma_max  \
# file                                               start  end
# D:\Projects\Speech_Depression\data\train\audio_... 0 days 0 days 00:00:52.500000               0.000178
#
#                                                                                   pcm_intensity_sma_min  \
# file                                               start  end
# D:\Projects\Speech_Depression\data\train\audio_... 0 days 0 days 00:00:52.500000           2.304610e-13
#
#                                                                                   pcm_intensity_sma_range  \
# file                                               start  end
# D:\Projects\Speech_Depression\data\train\audio_... 0 days 0 days 00:00:52.500000                 0.000178
#
#                                                                                   pcm_intensity_sma_maxPos  \
# ...
